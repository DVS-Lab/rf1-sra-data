# %%
import pandas as pd
import os
import json

# %%
os.listdir("../derivatives/mriqc/")
# Out:
# ['sub-10186_task-sharedreward_acq-mb1me4_echo-1_bold.html',
#  'sub-10154',
#  'sub-10136_task-sharedreward_acq-mb6me4_echo-4_bold.html',
#  'sub-10186_task-sharedreward_acq-mb6me1_bold.html',
#  'sub-10024_task-sharedreward_acq-mb3me4_echo-3_bold.html',
#  'sub-10085_task-sharedreward_acq-mb6me4_echo-2_bold.html',
#  'sub-10150_task-sharedreward_acq-mb6me4_echo-4_bold.html',
#  'sub-10108_task-sharedreward_acq-mb6me4_echo-3_bold.html',
#  'sub-10150_task-sharedreward_acq-mb3me4_echo-4_bold.html',
#  'sub-10130_task-sharedreward_acq-mb3me4_echo-1_bold.html',
#  'sub-10137_task-sharedreward_acq-mb3me1_bold.html',
#  'sub-10078_task-sharedreward_acq-mb3me4_echo-4_bold.html',
#  'sub-10078_task-sharedreward_acq-mb1me4_echo-1_bold.html',
#  'sub-10017_task-sharedreward_acq-mb3me4_echo-1_bold.html',
#  'sub-10035_task-sharedreward_acq-mb1me4_echo-2_bold.html',
#  'sub-10041',
#  'sub-10108_task-sharedreward_acq-mb6me4_echo-1_bold.html',
# ...

# %%
# Out:
# 0.10232502790103751
